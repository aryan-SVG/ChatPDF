# %%
import os
import shutil
import glob
from dotenv import load_dotenv
import gradio as gr

# %%
from langchain.document_loaders import DirectoryLoader, TextLoader, PyPDFLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.schema import Document
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_chroma import Chroma
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import numpy as np
import plotly.graph_objects as go
from langchain.memory import ConversationBufferMemory
from langchain.chains import ConversationalRetrievalChain
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.prompts import SystemMessagePromptTemplate, ChatPromptTemplate, HumanMessagePromptTemplate
import gradio as gr
from langchain_groq import ChatGroq

# %%
MODEL = "llama-3.3-70b-versatile"
db_name = "vector_db"

# %%
load_dotenv(override=True)
os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY')
os.environ['GROQ_API_KEY'] = os.getenv('GROQ_API_KEY')

# %%
import glob
import os
from langchain.document_loaders import DirectoryLoader, PyPDFLoader
from langchain.text_splitter import CharacterTextSplitter

folders = glob.glob("knowledge-base/*")

def add_metadata(doc, doc_type):
    doc.metadata["doc_type"] = doc_type
    return doc

def load_documents_from_folders(folders):
    documents = []
    for folder in folders:
        doc_type = os.path.basename(folder)
        loader = DirectoryLoader(
            folder,
            glob="**/*.pdf",
            loader_cls=PyPDFLoader 
        )
        folder_docs = loader.load()
        documents.extend([add_metadata(doc, doc_type) for doc in folder_docs])
    return documents

# %%
from langchain.schema import Document
from langchain.prompts import ChatPromptTemplate
from langchain.chains import LLMChain
import json

def create_profiles(documents):
    profiles = []
    for doc in documents:
        text = doc.page_content
        llm = ChatGroq(temperature=1, model=MODEL)
        prompt_template = ChatPromptTemplate.from_template(
            """
            Extract each profile from the following text.
            Return a JSON object, without any text surrounding it, Not even ```json..```,, 
            where each item has: "name", "title", "company", "description", etc.
            Text:
            ---
            {text}
            ---
            """
        )
        chain = LLMChain(llm=llm, prompt=prompt_template)
        result = chain.run({"text": text})
        # print(f"Result1 : {result}")
        items = json.loads(result)
        print(items)
        print(type(items))
        # for item in result:
        #     print(item)
        #     profiles.append(item)
        for item in items:
            profiles.append(str(item))
    return profiles

# %%
def create_vectorstore_from_profiles(profiles):
    agent_chunks = []
    for profile in profiles:
        profile_doc = Document(
                    page_content=profile,
                )
        agent_chunks.append(profile_doc)

    embeddings = OpenAIEmbeddings()
    if os.path.exists(db_name):
        Chroma(persist_directory=db_name, embedding_function=embeddings).delete_collection()
    vectorstore = Chroma.from_documents(
        documents=agent_chunks,
        embedding=embeddings,
        persist_directory=db_name
    )
    print(f"✅ Vectorstore created with {vectorstore._collection.count()} agent profiles.")
    return vectorstore

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Globals & Setup
# ─────────────────────────────────────────────────────────────────────────────
UPLOAD_DIR = "C:/Users/nisar/Desktop/Applications/Processes/Sociosquares/Projects/projects/llm_engineering/Provisor_project/knowledge-base/uploads"
vectorstore = None
user_business = None  
referral_types = None 

llm = ChatGroq(temperature=1, model=MODEL)
memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True)

extract_prompt = ChatPromptTemplate.from_template("""
From the conversation below, extract two things:
1) business: What business the user is in (if they've told you yet).
2) referral_types: The kinds of referral partners the user wants (as a comma-separated string).

If the user hasn’t provided one or both, set its value to an empty string.

Return a JSON object exactly like without any text surrounding it, Not even ```json..```:
{{  
  "business": "...",  
  "referral_types": "..."  
}}

Conversation:
---
{history}
---  
""")
extract_chain = LLMChain(llm=llm, prompt=extract_prompt)

def handle_pdf_upload(files):
    global vectorstore
    if not files:
        return "No files uploaded."
    os.makedirs(UPLOAD_DIR, exist_ok=True)
    for f in files:
        dest = os.path.join(UPLOAD_DIR, os.path.basename(f.name))
        shutil.copy(f.name, dest)
    docs = load_documents_from_folders([UPLOAD_DIR])
    profiles = create_profiles(docs)
    vectorstore = create_vectorstore_from_profiles(profiles)
    return f"{len(files)} PDF(s) processed and added to the vectorstore."


def qna_chat(user_message, history):
    global user_business, referral_types, vectorstore

    if vectorstore is None:
        return "📂 Please upload and process your PDFs before chatting."

    convo = []
    for u, a in history:
        convo.append(f"User: {u}")
        convo.append(f"Assistant: {a}")
    convo.append(f"User: {user_message}")
    history_str = "\n".join(convo)

    extracted = extract_chain.run({"history": history_str})
    print(f"Extracted: {extracted}")
    data = json.loads(extracted)
    if not user_business and data.get("business"):
        user_business = data["business"].strip()
    if not referral_types and data.get("referral_types"):
        referral_types = data["referral_types"].strip()

    if not user_business or not referral_types:
        return llm.invoke([{"role":"system","content":
            "You are an expert assistant who guides a user to find referral partners. "
            "First ask what business they are in, then ask who good referral partners are. "
            "Wait until both are given."
        }, 
        {"role":"user","content": history_str}]).content

    semantic_query = (
        f"I am in the {user_business} business and want referral partners who are {referral_types}."
    )
    retriever = vectorstore.as_retriever()
    system_prompt = SystemMessagePromptTemplate.from_template(
        "You are an expert assistant matching users to business referral contacts only from the retrieved documents. "
    )
    human_prompt = HumanMessagePromptTemplate.from_template(
        "Context:\n{context}\n\nQuestion: {question}"
    )
    chat_prompt = ChatPromptTemplate.from_messages([system_prompt, human_prompt])
    convo_chain = ConversationalRetrievalChain.from_llm(
        llm=llm,
        retriever=retriever,
        memory=memory,
        combine_docs_chain_kwargs={"prompt": chat_prompt}
    )
    result = convo_chain({"question": semantic_query})
    return result["answer"]


def reset_state():
    global user_business, referral_types, memory
    user_business = None
    referral_types = None
    memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True)
    return "🔄 Search reset! Please tell me what business you are in."

# ─────────────────────────────────────────────────────────────────────────────
# Gradio App
# ─────────────────────────────────────────────────────────────────────────────
with gr.Blocks() as demo:
    gr.Markdown("## 🤖 Referral Partner Finder")
    with gr.Row():
        uploader = gr.File(
            label="Upload Agent Profile PDFs",
            file_types=[".pdf"],
            file_count="multiple"
        )
        up_out = gr.Textbox(label="Status")
        reset_btn   = gr.Button("🔄 Restart Search")
        reset_status = gr.Textbox(label="Reset Status")
    gr.Button("Process PDFs").click(
        fn=handle_pdf_upload, inputs=uploader, outputs=up_out
    )
    reset_btn.click(fn=reset_state, inputs=[], outputs=reset_status)

    gr.ChatInterface(
        fn=qna_chat,
        title="Referral Partner Q&A",
        description="Bot will guide you through a few questions, then find matching profiles.",
        chatbot=gr.Chatbot()
    )

demo.launch(inbrowser=True)
# Out:
# C:\Users\nisar\AppData\Local\Temp\ipykernel_22580\4284320948.py:126: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot=gr.Chatbot()
# c:\Users\nisar\Desktop\Applications\Processes\Sociosquares\Projects\projects\llm_engineering\llms\lib\site-packages\gradio\chat_interface.py:321: UserWarning: The gr.ChatInterface was not provided with a type, so the type of the gr.Chatbot, 'tuples', will be used.
#   warnings.warn(
# * Running on local URL:  http://127.0.0.1:7906
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7906/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# {'profiles': [{'name': 'Angela Cearns', 'title': 'Consultant & Service', 'company': 'Ask Kevin', 'description': '', 'location': 'San Francisco, CA United States', 'phone': '650.733.9898', 'email': 'angela@askevin.com', 'website': 'https://www.askevin.com/aboutus'}, {'name': 'Jonathan Bello', 'title': 'Founder/CEO & Principal Accountant', 'company': 'One 8 Solutions, LLC', 'description': 'Numbers tell half the story. Let us show you the rest. We are a Client Accounting Services (CAS) firm acting as an outsourced accounting department where bookkeeping is a component of those services.', 'location': 'W Newton, MA 02465 United States', 'phone': '617-332-8522', 'email': 'jbello@one-8.com', 'website': 'www.one8solutions.com'}, {'name': 'Carrie Beam', 'title': 'Data Scientist', 'company': 'Carrie Beam Consulting', 'description': 'Fractional data scientist: user requirements, data architecture, algorithm selection and design. Analytics.', 'location': 'Walnut Creek, CA 94596 United States', 'phone': '925 285 1977', 'email': 'carrie@carriebeamconsulting.com', 'website': ''}, {'name': 'Nancy Barrett', 'title': 'Managing Director - Wealth Management', 'company': 'UBS Financial Services', 'description': 'Experienced financial services professional providing comprehensive wealth management for individuals and families with $5MM in investable assets. Wealth planning, investment management, banking, lending & insurance.', 'location': 'San Francisco, CA 94104 United States', 'phone': '415.954.6872', 'email': 'nancy.barrett@ubs.com', 'website': 'www.ubs.com'}, {'name': 'Andy Armstrong', 'title': 'Audit Partner', 'company': 'Armanino', 'description': 'Andy is an audit partner in San Jose with Armanino. He audits and consults venture-backed start-ups, family-owned businesses, entrepreneur-owned businesses and employee benefit plans.', 'location': 'San Jose, 95113', 'phone': '(669) 842-3465', 'email': 'andrew.armstrong@armanino.com', 'website': ''}]}
# <class 'dict'>
# {'profiles': [{'name': 'Shawn Flynn', 'title': 'Principal', 'company': 'Global Capital Markets', 'description': 'FINRA Licensed Investment Banker Focused on Mergers & Acquisitions, Raising Growth Capital, Secondary’s and Host of The Silicon Valley Podcast.', 'address': '279 Thatcher Ln, Foster City, CA 94404 United States', 'phone': '415 952 3165', 'email': 'sf@globalcapitalmarkets.com', 'website': 'https://www.globalcapitalmarkets.com/'}, {'name': 'Carver Farrow', 'title': 'Principal Attorney', 'company': 'FarrowLaw PC', 'description': '', 'address': '809 Cuesta Dr, Suite B - PMB 5021, Mountain View, CA 94040 United States', 'phone': '4084599206', 'email': 'carver@farrowlawfirm.esq'}, {'name': 'Kristopher Duarte', 'title': 'Executive Director', 'company': 'J.P. Morgan Chase & Co.', 'description': 'Blue Collar Banker Global Commercial Banking Local International Bank Manufacturing Wholesale Distribution Food Middle Market Food Logistics Transportation Janitorial Building Maintenance Paper Packaging Aerospace Debt ABL FX Foreign Exchange', 'address': 'Morgan Hill, CA United States', 'phone': '(408) 839-6586', 'email': 'k.c.duarte@chase.com', 'website': 'https://www.jpmorgan.com/commercial-banking'}, {'name': 'Manoj Dandekar PhD', 'title': 'Managing Director', 'company': 'Enterprise Economic Evaluation', 'description': 'Over 30 years of experience in the valuation of: * intangible assets (such as customer lists and relationships, proprietary technology, know how, recipes, etc.) and * intellectual property (domain names, patents, software, etc.)', 'address': '1608 W. Campbell Ave Suite 178, Campbell, 95008', 'phone': '650.224.1489', 'email': 'manoj@3isgroup.com', 'website': '3isgroup.com'}, {'name': 'Ed Correia', 'title': 'President', 'company': 'Sagacent Technologies', 'description': 'I protect businesses with sensitive data and regulatory concerns. Whether preventing issues or responding to breaches, ransomware, fraud, or email compromise, we deliver the IT management, security and compliance solutions they need.', 'address': '2010 El Camino Real # 766, Santa Clara, CA 95050-4051 United States', 'phone': '(408) 478-2597', 'email': 'ecorreia@sagacent.com', 'website': 'www.sagacent.com'}]}
# <class 'dict'>
# {'profiles': [{'name': 'Michelle Hoover', 'title': 'Director of Community Relations', 'company': 'Hoover Krepelka, LLP', 'description': "Trusted advisor network manager and community engagement director at Northern California's largest family law firm.", 'address': '1520 The Alameda, Suite 200, San Jose, CA 95126-2335 United States', 'phone': '(408) 947-7600', 'email': 'michelle.hoover@hooverkrepelka.com', 'website': 'www.hooverkrepelka.com', 'affiliations': ["Silicon Valley Women's Affinity Group", 'Mountain View 1 (GLA)']}, {'name': 'Sara Hire', 'title': 'Associate', 'company': 'Lathrop GPM LLP', 'description': 'I educate, assist and advocate for my clients who have complex assets or are high net worth ($7M+) in the field of estate planning.', 'address': '70 South First Street, San Jose, CA 95113 United States', 'phone': '(408) 299-1376', 'email': 'sara.hire@lathropgpm.com', 'website': 'https://www.lathropgpm.com/', 'affiliations': ['Mountain View 1', 'San Diego Estate and Succession Planning Affinity Group', "Silicon Valley Women's Affinity Group"]}, {'name': 'Dina Haddad', 'title': 'Attorney', 'company': 'Families First Mediation', 'description': 'We put your client & their spouse in control of their divorce process. We serve a broad range of Californians from teachers to co-founders.', 'address': 'San Jose, CA 95125 United States', 'phone': '408-357-3486', 'email': 'dina@ffmediation.com', 'website': 'https://ffmediation.com; https://thecompletedivorce.com', 'affiliations': ['Silicon Valley Attorneys Affinity Group', 'Mountain View 1', "Bay Area Women's Affinity Group"]}, {'name': 'Lauren Gray', 'title': 'Senior Financial Advisor', 'company': 'Merrill Lynch Wealth Management', 'description': 'I provide goals-based wealth management to affluent families, accomplished professionals and successful business owners.', 'address': '50 W San Fernando St 16th floor, San Jose, CA 95113 United States', 'phone': '(408) 283-3134', 'email': 'lauren.madergray@ml.com', 'website': 'www.fa.ml.com/lauren-madergray', 'affiliations': ['Mountain View 1']}, {'name': 'Alan Foster', 'title': 'Principal Attorney', 'company': 'Foster Law Group', 'description': 'Alan is a business and corporate attorney who counsels small businesses that offer a wide range of products and services.', 'address': '5201 Great America Parkway, Suite 320, Santa Clara, CA 95054 United States', 'phone': '(408) 785-8510', 'email': 'afoster@fosterlawgroup.us', 'website': 'www.fosterlawgroup.us', 'affiliations': ['Mountain View 1']}]}
# <class 'dict'>
# [{'name': 'Devi McFadden', 'title': 'Executive Coach', 'company': 'Kathy Devi McFadden LLC', 'description': 'I am an Executive Coach specializing in authentic leadership, influence and building high-performing teams. I help tech executives expand their influence and drive results while thriving professionally and personally.', 'address': '311 Bar King Road, Boulder Creek, CA 95006 United States', 'phone': '(408) 759-4574', 'email': 'devi@kathydevimcfadden.com', 'website': 'kathydevimcfadden.com'}, {'name': 'Peter Malutta', 'title': 'Accountant', 'company': 'PP&Co', 'description': 'Tax planning and compliance for family owned businesses, high net worth individuals, and estates and trusts.', 'address': '333 W. Santa Clara St., Suite 750, San Jose, CA 95113 United States', 'phone': '(408) 464-1137', 'email': 'pmalutta@ppandco.com', 'website': 'https://www.ppandco.com/'}, {'name': 'Brad Lambert', 'title': 'Private Bank Market Leader', 'company': 'PNC Private Bank', 'description': '', 'address': '1112 Nevada Ave., San Jose, CA 95125 United States', 'phone': '415-805-3109', 'email': 'bradley.lambert@pnc.com'}, {'name': 'Dawn Knepper', 'title': 'Employment Attorney', 'company': 'Knepper Law PC', 'description': 'Dawn is passionate about helping individuals work through issues with their employers, from contract review to evaluating legal options to litigation. Dawn draws on her 20 years of experience of representing management to fight for the best outcome.', 'address': '100 Spectrum Center Drive, Suite 900, IRVINE, CA 92618 United States', 'phone': '(949) 416-2020', 'email': 'dknepper@knepper.law', 'website': 'Knepper Law PC'}, {'name': 'Yong Jeon', 'title': 'Tax Partner', 'company': 'Brayn Consulting LLC', 'description': 'Tax incentives / Architects / Engineers / Construction / Real Estate Investors builders / R&D tax credit / Cost Segregation / Energy Tax Incentives / 179D / 45L / Investment Tax Credit / Industry Tax and Design Experience', 'address': 'San Francisco, CA 94105 United States', 'phone': '510-289-8619', 'email': 'yong@brayn.com', 'website': 'brayn.com'}]
# <class 'list'>
# [{'name': 'Tamara Pow', 'title': 'Business and Real Estate Attorney', 'company': 'Strategy Law, LLP', 'position': 'Attorney', 'description': 'I protect real estate investors and closely held business owners from liability in purchases, sales, leases, limited liability companies (LLCs), partnerships (JV, LP, LLP, law firm agreements) and corporations.', 'address': '1 Almaden Blvd., Suite 700, San Jose, CA 95113 United States', 'phone': '(408) 478-4100', 'email': 'tpow@strategylaw.com', 'website': 'www.strategylaw.com', 'affiliations': ["Silicon Valley Women's Affinity Group", 'Silicon Valley Real Estate Affinity Group', 'Silicon Valley Attorneys Affinity Group', 'Mountain View 1 (TM)']}, {'name': 'Lisa Petrocchi-Merriman', 'pronouns': 'she/her', 'title': 'Business Coach and Program Leader & Executive Leadership Coach', 'company': 'Mark Kamin & Associates', 'position': 'Consultant & Service', 'description': 'I am an executive development business coach with Mark Kamin & Associates. I work with companies on organizational culture change improving leadership & team communication by balancing humanity with high performing productivity in companies of all sizes.', 'address': '949 NE Hazelfern Place, Portland, OR 97232 United States', 'phone': '669.208.2194', 'email': 'l.merriman@mka-world.com', 'website': 'www.mka-world.com', 'affiliations': ['Silicon Valley Virtual 1']}, {'name': 'Shana Nelson', 'title': 'President', 'company': 'Shana Nelson Insurance Agency Inc', 'position': 'Insurance', 'description': 'Shana Nelson has been the Agent/owner of her boutique State Farm Insurance Agency since 1998, In Mountain View since 2000. The agency team of 6 who are all licensed and experienced work to assist clients in regularly assessing their current exposures', 'address': '10011 N Foothill Blvd, ste 111, Cupertino, CA 95014 United States', 'phone': '650.988.8990', 'email': 'shana.nelson.lnoy@statefarm.com', 'website': 'www.ShanaNelson.com', 'affiliations': ['Mountain View 1']}, {'name': 'Jonna Mooney', 'title': 'Principal', 'company': 'Affogato HR Consulting', 'position': 'Human Resources', 'description': 'I am an HR Management Consultant advising small to mid-sized companies in any industry in any location.', 'address': 'Affogato HR Consulting LLC PO Box 8132, San Jose, CA 95155 United States', 'phone': '408.933.3020 x700', 'email': 'jonna@affogatohr.com', 'website': 'www.affogatohr.com', 'affiliations': ['Mountain View 1', "Silicon Valley Women's Affinity Group"]}, {'name': 'Gaurav (Rav) Mendiratta', 'title': 'CEO', 'company': 'SocioSquares', 'position': 'Marketing', 'description': 'We help Law Firms show up higher on Google and generate more leads with AI, SEO and Google Reviews.', 'address': '2450 Peralta Blvd, #221, Fremont, CA 94536 United States', 'phone': '(215) 253-5622', 'email': 'gaurav@sociosquares.com', 'website': 'www.sociosquares.com', 'affiliations': ['Mountain View 1']}]
# <class 'list'>
# [{'name': 'Ben Stoddard', 'title': 'Trial Attorney', 'company': 'Sigala & Stoddard LLP', 'type': 'Attorney', 'description': 'Attorney representing victims in wrongful death and catastrophic injury cases. Largest wrongful death settlement in California in 2019.', 'address': '96 N. 3rd Street, 620, San Jose, CA 95112 United States', 'phone': '(408) 298-7200', 'email': 'bstoddard@sigstod.com', 'website': 'www.sigstod.com'}, {'name': 'Victoria Rayman', 'pronouns': 'she/her', 'title': 'Associate Attorney', 'company': 'Copenbarger & Copenbarger', 'type': 'Attorney', 'description': 'Estate Planning Attorney for California', 'address': '1737 N 1st Street, Suite 270, San Jose, CA 95112 United States', 'phone': '(949) 667-3370', 'email': 'victoria@copenbarger.com', 'website': 'copenbarger.com'}, {'name': 'Pete Ravani', 'title': '401(k) Specialist', 'company': 'Ravani Retirement & Wealth Solutions, World Investment Advisors', 'type': 'Consultant & Service', 'description': '401(k) Specialist helping mid to large employers meet their fiduciary obligation to lower plan fees and offer best in class investment lineup. And help highly profitable closely-held businesses establish a pension plan to lower taxable income', 'address': 'PO Box 885, Cupertino, CA 95015 United States', 'phone': '424-208-9913', 'email': 'pete.ravani@worldadvisors.com', 'website': 'https://worldadvisors.com/'}, {'name': 'Ricardo Ramirez', 'pronouns': 'he/him', 'title': 'Member', 'company': 'Silicon Valley Criminal Law Group, PC', 'type': 'Attorney', 'description': 'Former Santa Clara County Deputy Public Defender. Over 5,000 criminal cases handled. Representing clients from San Francisco to Monterey and every county in between. Traffic tickets, DUIs, Domestic violence, expungements, any criminal allegation.', 'address': '3031 Tisch Way, #110 Plaza West, San Jose, CA 95128 United States', 'phone': '4087853415', 'email': 'ricardo@svcriminallaw.com', 'website': 'https://svcriminallaw.com/'}, {'name': 'Jenn Protas', 'title': 'Shareholder / Attorney', 'company': 'Hoge Fenton Jones & Appel, Inc.', 'type': 'Attorney', 'description': 'I help employers navigate California’s numerous employment laws and defend employers with an eye toward successful, yet cost-effective resolution.', 'address': '55 South Market Street, Suite 900, San Jose, CA 95113 United States', 'phone': '408.947.2435', 'email': 'jenn.protas@hogefenton.com', 'website': 'https://www.hogefenton.com/', 'roles': ['Host', 'EC', 'DEI Ambassador']}]
# <class 'list'>
# {'profiles': [{'name': 'Michelle Thompson', 'title': 'Realtor', 'company': 'Keller Williams Silicon Valley', 'industry': 'Real Estate', 'description': 'Residential Real Estate in the Bay Area. Connecting Hearts to Homes. I assist buyers, sellers, and investors. Extensive agent network for relocating buyers & sellers.', 'address': '2110 S Bascom Ave, Ste 101, Campbell, CA 95008, United States', 'phone': '(408) 839-4436', 'email': 'michelle.thompson@kw.com', 'website': 'https://lisa2homes.com/our-team/', 'affinityGroups': ['Mountain View 1', "Silicon Valley Women's Affinity Group", 'Bay Area Real Estate Affinity Group']}, {'name': 'Dawn Thomas', 'title': 'Broker Associate, Realtor', 'company': 'Compass Silicon Valley', 'industry': 'Real Estate', 'description': 'Probate, Divorce, and Luxury Certified Residential REALTOR in Silicon Valley. With extensive experience in the luxury market, I assist lifestyle sellers, buyers, relocation clients, move-up buyers, and empty nesters across all price points, up to $45M.', 'address': '750 University Avenue, #150, Los Gatos, CA 95032, United States', 'phone': '(650) 215-5990', 'email': 'dawn@siliconvalleyandbeyond.com', 'website': 'http://www.SiliconValleyandBeyond.com', 'affinityGroups': ['Silicon Valley Real Estate Affinity Group', 'Mountain View 1', 'Silicon Valley Estate and Succession Planning Affinity Group', "Bay Area Women's Affinity Group", "Silicon Valley Women's Affinity Group"]}, {'name': 'Kevin Symes', 'title': 'Regional Business Development Director', 'company': 'TheKey by Home Care Assistance', 'industry': 'Consultant & Service', 'description': 'I have a background in Business Development with over 10 years of experience. I get excited for the opportunity to support others in their journey. My primary role is providing a quality care team for those in the senior population.', 'address': '985 University Ave. #6, LOS GATOS, CA 95032, United States', 'phone': '(408) 206-0590', 'email': 'ksymes@thekey.com', 'website': 'https://www.thekey.com/san-jose-area', 'affinityGroups': ['Mountain View 1']}, {'name': 'Peter Stone', 'title': 'Shareholder', 'company': 'Ridgeline Law Office, Inc.', 'industry': 'Attorney', 'description': 'Peter Stone is a shareholder of Ridgeline Law Office, Inc. He is a corporate and commercial transactions lawyer who serves as Outside General Counsel to entrepreneurs and businesses from start-up stage through emerging growth stage.', 'address': '3450 Sacramento Street #250, San Francisco, CA 94118, United States', 'phone': '(408) 219-4786', 'email': 'pstone@ridgelinelawoffice.com', 'website': 'ridgelinelawoffice.com', 'affinityGroups': ['Silicon Valley Estate and Succession Planning Affinity Group', 'Bay Area Lawyers Affinity Group', 'Bay Area Middle Market Affinity Group', 'Silicon Valley Attorneys Affinity Group', 'Silicon Valley Mergers & Acquisitions Affinity Group', 'San Jose 1']}]}
# <class 'dict'>
# [{'name': 'Richard Wang', 'title': 'Mortgage Broker', 'company': 'Veridian Mortgage, LLC', 'description': 'Mortgage broker and attorney with the knowledge, experience, program suite and Disney-level service to assist first-time buyers, self-employed, or retired applicants.', 'address': '2975 Bowers Avenue, Suite 315, Santa Clara, CA 95051 United States', 'phone': '(408) 828-5609', 'email': 'richard@veridianmortgage.com', 'website': 'www.veridianmortgage.com', 'groups': ['LGBTQ+Allies Affinity Group', 'Silicon Valley Real Estate Affinity Group', 'Group Leader Acceleration Meeting', 'Sacramento 1 (GLA)', 'Newport Center 2', 'LAX/Long Beach Real Estate Affinity', 'Bay Area Lawyers Affinity Group', 'SF Estate and Succession Planning Affinity Group', 'Silicon Valley Attorneys Affinity Group', 'Mountain View 1 (GL)', 'San Jose 4 (EC)', 'San Francisco 6', 'Bay Area Real Estate Affinity Group']}, {'name': 'Maya Tussing', 'title': 'Nonprofit/Tax-Exempt Org Resilience Advisor', 'company': 'Fairlight Advisors LLC', 'description': 'We help nonprofits going through strategic change be financially resilient to deliver more philanthropic impact.', 'address': '505 Montgomery Street, Fl 10, San Francisco, CA 94111 United States', 'phone': '(415) 999-4344', 'email': 'maya@fairlightadvisors.com', 'groups': ['Group Leader Acceleration Meeting', 'Mountain View 1 (GLA)', "Bay Area Women's Affinity Group", "PNW Women's Affinity Group", 'Seattle 1 (GL)']}, {'name': 'Sophie Tsang', 'title': 'MBA, Broker Lic. #01399145', 'company': 'Compass Palo Alto', 'description': "America's Best-WSJ Real Trends 2024. 20+ years in marketing residential properties, experienced in Probate, Trust, Divorce sales.", 'address': '578 University Ave, Palo Alto, CA 94301 United States', 'phone': '(408) 667-3171', 'email': 'sophie@compass.com', 'website': 'SophieTsang.com', 'groups': ["Silicon Valley Women's Affinity Group", 'Palo Alto 3', 'Silicon Valley Real Estate Affinity Group', 'San Francisco 12', 'SF Estate and Succession Planning Affinity Group', 'Bay Area Real Estate Affinity Group', 'Bay Area International Affinity Group', "Bay Area Women's Affinity Group"]}, {'name': 'Cara Trapani', 'title': 'Attorney | Workplace & Title IX Investigations', 'company': 'Buehler Trapani LLP', 'description': 'I conduct Title IX sexual misconduct investigations for K-12 schools and universities, and impartial, third-party workplace investigations for employers who receive employee complaints of discrimination, harassment, and retaliation.', 'address': '1966 Tice Valley Blvd, PMB 120, Walnut Creek, CA 94595-2203 United States', 'phone': '(415) 272-4631', 'email': 'cara@btinvestigates.com', 'website': 'https://btinvestigates.com/', 'groups': ["Bay Area Women's Affinity Group", 'Walnut Creek 2 (EC)', "East Bay Women's Affinity Group", 'Bay Area Lawyers Affinity Group']}]
# <class 'list'>
# [{'name': 'Nico Wiborg', 'title': 'Agent', 'company': 'New York Life', 'industry': 'Financial Service', 'description': 'Works with business owners, executives and their families. Specializes in life insurance, disability insurance and long term care insurance.', 'address': '25 Metro Drive #300, San Jose, CA 95110 United States', 'phone': '(408) 655-5964', 'email': 'nwiborg@ft.newyorklife.com', 'affiliations': ['Group Leader Acceleration Meeting, Santa Clara 1', 'Bay Area Distributors & Manufacturers Affinity Group, San Jose 2']}, {'name': 'Zach Whitman', 'title': 'Agent and Registered Representative CA', 'company': 'New York Life Insurance Company', 'industry': 'Insurance', 'description': 'Provides risk management and tax strategic business, personal and retirement planning utilizing life insurance, disability insurance, long term care insurance, annuity and investment products.', 'address': '26 Selby Lane, Atherton, CA 94027 United States', 'phone': '(650) 562-7323', 'email': 'zewhitman@ft.newyorklife.com', 'website': 'www.newyorklife.com', 'license': 'CA INSURANCE LIC #0E13098', 'affiliations': ['Silicon Valley Mergers & Acquisitions Affinity Group, Mountain View 1', 'Silicon Valley Estate and Succession Planning Affinity Group']}, {'name': 'Todd Wellnitz', 'title': 'Independent Insurance Broker', 'company': 'Wellguard Insurance & Financial', 'industry': 'Insurance', 'description': 'LIFESTYLE Insurance Advocate protecting, replacing & guaranteeing INCOME streams...frequently income TAX FREE! Specializing in Life Insurance, Disability, Long Term Care, Structured Settlements, Income Annuity & Estate Planning', 'address': '1516 Oak St. #304, Alameda, CA 94501', 'phone': '(415) 846-1521', 'email': 'todd@wellguardfinancial.com', 'website': 'www.WellguardFinancial.com', 'affiliations': ['Walnut Creek 1 (EC)', 'SF Estate and Succession Planning Affinity Group, Bay Area Real Estate Affinity Group']}]
# <class 'list'>
# ✅ Vectorstore created with 26 agent profiles.

# %%
#Tool is user specific.
